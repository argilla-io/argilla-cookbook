# %% [markdown]
# # Label datasets with LLMs, good annotation guidelines, and distilabel
#
# In this notebook, we will use the `distilabel` library to label datasets with LLMs. We will use the `ArgillaLabeller` class to label any dataset that is hosted on Argilla with based on the written dataset definitions, like guidelines, fields, and questions. This is cool because you can use the same labelling interface for any dataset and questions that is hosted on Argilla.

# %% [markdown]
# ## Getting started
#
# ### Deploy the Argilla server¶
#
# If you already have deployed Argilla, you can skip this step. Otherwise, you can quickly deploy Argilla following [this guide](https://docs.argilla.io/latest/getting_started/quickstart/).
#
# ### Install dependencies

# %%
# %pip install "git+https://github.com/argilla-io/distilabel.git@develop#egg=distilabel[argilla,llama_cpp,outlines]"
# !pip install numpy==1.26.4
# !pip install outlines==0.0.36
# !pip install llama_cpp_python==0.2.85
# Out:
# DEPRECATION: git+https://github.com/argilla-io/distilabel.git@develop#egg=distilabel[argilla,llama_cpp,outlines] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting distilabel (from distilabel[argilla,llama_cpp,outlines])
#   Cloning https://github.com/argilla-io/distilabel.git (to revision develop) to /private/var/folders/9t/msy700h16jz3q35qvg4z1ln40000gn/T/pip-install-k_xp9cij/distilabel_3660aa26060c4e56a32016d3f61de7bd
#   Running command git clone --filter=blob:none --quiet https://github.com/argilla-io/distilabel.git /private/var/folders/9t/msy700h16jz3q35qvg4z1ln40000gn/T/pip-install-k_xp9cij/distilabel_3660aa26060c4e56a32016d3f61de7bd
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   branch 'develop' set up to track 'origin/develop'.
#   Resolved https://github.com/argilla-io/distilabel.git to commit b4c13ba5d573dca178992ecd0e6ed3b546b0bc57
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets>=2.16.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (3.0.1)
# Requirement already satisfied: httpx>=0.25.2 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (0.27.2)
# Requirement already satisfied: jinja2>=3.1.2 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (3.1.4)
# Requirement already satisfied: multiprocess>=0.70 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (0.70.16)
# Requirement already satisfied: nest-asyncio>=1.6.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (3.3)
# Requirement already satisfied: orjson>=3.10.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (3.10.7)
# Requirement already satisfied: portalocker>=2.8.2 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (2.10.1)
# Requirement already satisfied: pydantic>=2.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (2.9.2)
# Requirement already satisfied: rich>=13.5.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (13.9.1)
# Requirement already satisfied: scipy>=1.10.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (1.14.1)
# Requirement already satisfied: tblib>=3.0.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (3.0.0)
# Requirement already satisfied: typer>=0.9.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (0.12.5)
# Requirement already satisfied: universal-pathlib>=0.2.2 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (0.2.5)
# Collecting outlines>=0.0.40 (from distilabel->distilabel[argilla,llama_cpp,outlines])
#   Using cached outlines-0.0.46-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: llama-cpp-python>=0.2.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (0.2.85)
# Requirement already satisfied: argilla>=2.0.0 in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (2.3.0)
# Requirement already satisfied: ipython in ./.env/lib/python3.10/site-packages (from distilabel->distilabel[argilla,llama_cpp,outlines]) (8.27.0)
# Requirement already satisfied: huggingface_hub>=0.22.0 in ./.env/lib/python3.10/site-packages (from argilla>=2.0.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.25.1)
# Requirement already satisfied: tqdm>=4.60.0 in ./.env/lib/python3.10/site-packages (from argilla>=2.0.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.66.5)
# Requirement already satisfied: pillow>=9.5.0 in ./.env/lib/python3.10/site-packages (from argilla>=2.0.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (10.4.0)
# Requirement already satisfied: filelock in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.3.8)
# Requirement already satisfied: pandas in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.32.3)
# Requirement already satisfied: xxhash in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.5.0)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in ./.env/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2024.6.1)
# Requirement already satisfied: aiohttp in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.10.8)
# Requirement already satisfied: packaging in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in ./.env/lib/python3.10/site-packages (from datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (6.0.2)
# Requirement already satisfied: anyio in ./.env/lib/python3.10/site-packages (from httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.6.0)
# Requirement already satisfied: certifi in ./.env/lib/python3.10/site-packages (from httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./.env/lib/python3.10/site-packages (from httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.0.6)
# Requirement already satisfied: idna in ./.env/lib/python3.10/site-packages (from httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.10)
# Requirement already satisfied: sniffio in ./.env/lib/python3.10/site-packages (from httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2>=3.1.2->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.1.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.env/lib/python3.10/site-packages (from llama-cpp-python>=0.2.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.12.2)
# Requirement already satisfied: diskcache>=5.6.1 in ./.env/lib/python3.10/site-packages (from llama-cpp-python>=0.2.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (5.6.3)
# Requirement already satisfied: interegular in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.3.3)
# Requirement already satisfied: lark in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.2.2)
# Requirement already satisfied: cloudpickle in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.0.0)
# Requirement already satisfied: numba in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.60.0)
# Requirement already satisfied: referencing in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.35.1)
# Requirement already satisfied: jsonschema in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.23.0)
# Requirement already satisfied: pycountry in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (24.6.1)
# Requirement already satisfied: pyairports in ./.env/lib/python3.10/site-packages (from outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.env/lib/python3.10/site-packages (from pydantic>=2.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.env/lib/python3.10/site-packages (from pydantic>=2.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.env/lib/python3.10/site-packages (from rich>=13.5.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.env/lib/python3.10/site-packages (from rich>=13.5.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in ./.env/lib/python3.10/site-packages (from typer>=0.9.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in ./.env/lib/python3.10/site-packages (from typer>=0.9.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.5.4)
# Requirement already satisfied: decorator in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.0.48)
# Requirement already satisfied: stack-data in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (5.14.3)
# Requirement already satisfied: exceptiongroup in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in ./.env/lib/python3.10/site-packages (from ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.env/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (4.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.env/lib/python3.10/site-packages (from jedi>=0.16->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in ./.env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.5.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.env/lib/python3.10/site-packages (from pexpect>4.3->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.env/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.2.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.env/lib/python3.10/site-packages (from jsonschema->outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.env/lib/python3.10/site-packages (from jsonschema->outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.20.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.env/lib/python3.10/site-packages (from numba->outlines>=0.0.40->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.env/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.env/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->distilabel->distilabel[argilla,llama_cpp,outlines]) (2024.2)
# Requirement already satisfied: executing>=1.2.0 in ./.env/lib/python3.10/site-packages (from stack-data->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.env/lib/python3.10/site-packages (from stack-data->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (2.4.1)
# Requirement already satisfied: pure-eval in ./.env/lib/python3.10/site-packages (from stack-data->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in ./.env/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython->distilabel->distilabel[argilla,llama_cpp,outlines]) (1.16.0)
# Using cached outlines-0.0.46-py3-none-any.whl (101 kB)
# Installing collected packages: outlines
#   Attempting uninstall: outlines
#     Found existing installation: outlines 0.0.36
#     Uninstalling outlines-0.0.36:
#       Successfully uninstalled outlines-0.0.36
# Successfully installed outlines-0.0.46
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy==1.26.4 in ./.env/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting outlines==0.0.36
#   Using cached outlines-0.0.36-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: interegular in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (0.3.3)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (3.1.4)
# Requirement already satisfied: lark in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (1.2.2)
# Requirement already satisfied: nest-asyncio in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (1.6.0)
# Requirement already satisfied: numpy in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (1.26.4)
# Requirement already satisfied: cloudpickle in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (3.0.0)
# Requirement already satisfied: diskcache in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (5.6.3)
# Requirement already satisfied: pydantic>=2.0 in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (2.9.2)
# Requirement already satisfied: scipy in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (1.14.1)
# Requirement already satisfied: torch>=2.1.0 in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (2.4.1)
# Requirement already satisfied: numba in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (0.60.0)
# Requirement already satisfied: joblib in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (1.4.2)
# Requirement already satisfied: referencing in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (0.35.1)
# Requirement already satisfied: jsonschema in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (4.23.0)
# Requirement already satisfied: requests in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (2.32.3)
# Requirement already satisfied: transformers in ./.env/lib/python3.10/site-packages (from outlines==0.0.36) (4.45.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.env/lib/python3.10/site-packages (from pydantic>=2.0->outlines==0.0.36) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.env/lib/python3.10/site-packages (from pydantic>=2.0->outlines==0.0.36) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.env/lib/python3.10/site-packages (from pydantic>=2.0->outlines==0.0.36) (4.12.2)
# Requirement already satisfied: filelock in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->outlines==0.0.36) (3.16.1)
# Requirement already satisfied: sympy in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->outlines==0.0.36) (1.13.3)
# Requirement already satisfied: networkx in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->outlines==0.0.36) (3.3)
# Requirement already satisfied: fsspec in ./.env/lib/python3.10/site-packages (from torch>=2.1.0->outlines==0.0.36) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2->outlines==0.0.36) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in ./.env/lib/python3.10/site-packages (from jsonschema->outlines==0.0.36) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.env/lib/python3.10/site-packages (from jsonschema->outlines==0.0.36) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.env/lib/python3.10/site-packages (from jsonschema->outlines==0.0.36) (0.20.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.env/lib/python3.10/site-packages (from numba->outlines==0.0.36) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.10/site-packages (from requests->outlines==0.0.36) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.10/site-packages (from requests->outlines==0.0.36) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.10/site-packages (from requests->outlines==0.0.36) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.10/site-packages (from requests->outlines==0.0.36) (2024.8.30)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in ./.env/lib/python3.10/site-packages (from transformers->outlines==0.0.36) (4.66.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.env/lib/python3.10/site-packages (from sympy->torch>=2.1.0->outlines==0.0.36) (1.3.0)
# Using cached outlines-0.0.36-py3-none-any.whl (79 kB)
# Installing collected packages: outlines
#   Attempting uninstall: outlines
#     Found existing installation: outlines 0.0.46
#     Uninstalling outlines-0.0.46:
#       Successfully uninstalled outlines-0.0.46
# Successfully installed outlines-0.0.36
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: llama_cpp_python==0.2.85 in ./.env/lib/python3.10/site-packages (0.2.85)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.env/lib/python3.10/site-packages (from llama_cpp_python==0.2.85) (4.12.2)
# Requirement already satisfied: numpy>=1.20.0 in ./.env/lib/python3.10/site-packages (from llama_cpp_python==0.2.85) (1.26.4)
# Requirement already satisfied: diskcache>=5.6.1 in ./.env/lib/python3.10/site-packages (from llama_cpp_python==0.2.85) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in ./.env/lib/python3.10/site-packages (from llama_cpp_python==0.2.85) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2>=2.11.3->llama_cpp_python==0.2.85) (2.1.5)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Download the model
#
# For the example, we will just use a [quantized version of llama 3.2 1B](https://huggingface.co/hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF/tree/main). This model will be good enough for basic labelling tasks.

# %%
url="https://huggingface.co/hugging-quants/Llama-3.2-1B-Instruct-Q8_0-GGUF/resolve/main/llama-3.2-1b-instruct-q8_0.gguf?download=true"
filename="llama-3.2-1b-instruct-q8_0.gguf"

import requests
import os

def download_file(url, filename):
    response = requests.get(url, stream=True)
    response.raise_for_status()
    
    with open(filename, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

if not os.path.exists(filename):
    print(f"Downloading {filename}...")
    download_file(url, filename)
    print(f"Download complete: {filename}")
else:
    print(f"{filename} already exists. Skipping download.")
# Out:
# Downloading llama-3.2-1b-instruct-q8_0.gguf...
# Download complete: llama-3.2-1b-instruct-q8_0.gguf

# %% [markdown]
# ## Upload some a basic datasets to Argilla
#
# We will now choose 4 datasets from Hugging Face and upload them to Argilla. A dataset each for the `TextQuestion` and `LabelQuestion`.
#
# - https://huggingface.co/datasets/dair-ai/emotion: emotions as classes
# - https://huggingface.co/datasets/fka/awesome-chatgpt-prompts: chatgpt prompts as text
#
# We will use the `rg.Dataset.from_hub` method to upload example datasets to Argilla. We will also use the `rg.Settings` class to map the fields to the questions.

# %%
import argilla as rg
import os

client = rg.Argilla(
    api_url=os.environ["ARGILLA_API_URL_DEV"], api_key=os.environ["ARGILLA_API_KEY_DEV"]
)

settings = rg.Settings(
    fields=[
        rg.TextField(
            name="prompt",
            title="Prompt",
            description="Provide a concise response to the prompt",
        )
    ],
    questions=[
        rg.TextQuestion(
            name="response",
            title="Response",
            description="Provide a concise response to the prompt",
        )
    ],
    mapping={"prompt": "prompt"},
)

rg.Dataset.from_hub(
    repo_id="fka/awesome-chatgpt-prompts",
    name="awesome-chatgpt-prompts",
    split="train[:100]",
    client=client,
    with_records=True,
    settings=settings,
)

settings = rg.Settings(
    fields=[
        rg.TextField(
            name="text",
            title="Text",
            description="Provide a concise response to the prompt",
        )
    ],
    questions=[
        rg.LabelQuestion(
            name="emotion",
            title="Emotion",
            description="Provide a single label for the emotion of the text",
            labels=["joy", "anger", "sadness", "fear", "surprise", "love"],
        )
    ],
    mapping={"text": "text"},
)

rg.Dataset.from_hub(
    repo_id="dair-ai/emotion",
    name="emotion",
    split="train[:100]",
    client=client,
    with_records=True,
    settings=settings,
)

# %% [markdown]
# ## Label the datasets
#
# We will now label the datasets. We will use the `ArgillaLabeller` class to label the datasets. This class will use  will use a `LlamaCppLLM` LLM to label the datasets. These labels will then be converted into `rg.Suggestion` objects and added to the records. For the sake of the example, we will only label 5 records per time using a while loop that continuesly fetches pending records from Argilla for both datasets and labels them with the LLM. After the labelling, we will update the dataset with the new records.

# %%
import os

import argilla as rg
from distilabel.llms.llamacpp import LlamaCppLLM
from distilabel.steps.tasks import ArgillaLabeller

client = rg.Argilla(
    api_url=os.environ["ARGILLA_API_URL_DEV"], api_key=os.environ["ARGILLA_API_KEY_DEV"]
)

# Initialize the labeller with the model and fields
labeller = ArgillaLabeller(
    llm=LlamaCppLLM(
        model_path="llama-3.2-1b-instruct-q8_0.gguf",
        n_ctx=8000,
        extra_kwargs={"max_new_tokens": 8000, "temperature": 0.0},
    )
)
labeller.load()

# Define the datasets, questions, and fields to use with the labeller
datasets = ["emotion", "awesome-chatgpt-prompts"]
fields: list[str] = ["text", "prompt"]
questions = ["emotion", "response"]

# Loop over the datasets, questions, and fields
while True:
    for dataset, question, field in zip(datasets, questions, fields):
        # Get information from Argilla dataset definition
        dataset = client.datasets(name=dataset, workspace="argilla")
        pending_records_filter = rg.Filter(("status", "==", "pending"))

        pending_records = list(
            dataset.records(
                query=rg.Query(filter=pending_records_filter),
                limit=1,
            )
        )
        field = dataset.settings.fields[field]
        question = dataset.settings.questions[question]

        # Process the pending records
        result = next(
            labeller.process(
                [
                    {
                        "record": record,
                        "fields": [field],
                        "question": question,
                        "guidelines": dataset.guidelines,
                    }
                    for record in pending_records
                ]
            )
        )

        # Add the suggestions to the records
        for record, suggestion in zip(pending_records, result):
            record.suggestions.add(rg.Suggestion(**suggestion["suggestion"]))

        # Log the updated records
        dataset.records.log(pending_records)

# %% [markdown]
# ![label dataset argilla labeller](./images/label_datasets%20with_llms_annotation_guidelines_and_distilabel.png)
